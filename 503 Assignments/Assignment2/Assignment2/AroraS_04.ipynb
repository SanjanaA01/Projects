# %% [markdown]
# # Student: Arora, Sanjana (V00966221)
# Question 4

# %% [markdown]
# ![Document 24_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Document 24_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Document 24_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Referred the lecture slides
